# %%
#python

import pandas as pd

from google.colab import drive
#drive.mount('/content/drive')
acres =pd.read_csv('/content/drive/MyDrive/capstone/MDAcres.csv')
eco = pd.read_csv('/content/drive/MyDrive/capstone/MDSocioeconomic.csv')
health = pd.read_csv('/content/drive/MyDrive/capstone/MDPhysicalActivity.csv')
parks = pd.read_csv('/content/drive/MyDrive/capstone/ParksData.csv')


#eco = pd.read_csv("MDAcres.csv")
print(parks)
# Out:
#                               Park Name      County  Unnamed: 2
# 0                          Baggett Park  St. Mary's         NaN
# 1                 Cardinal Gibbons Park  St. Mary's         NaN
# 2         Carver Heights Community Park  St. Mary's         NaN
# 3                            Cecil Park  St. Mary's         NaN
# 4        Chancellor’s Run Regional Park  St. Mary's         NaN
# ...                                 ...         ...         ...
# 2091        Curtis Harvey Memorial Park    Caroline         NaN
# 2092         North County Regional Park    Caroline         NaN
# 2093       Christian (Red Bridges) Park    Caroline         NaN
# 2094                 Sunset Avenue Park    Caroline         NaN
# 2095  Idylwild Wildlife Management Area    Caroline         NaN
#
# [2096 rows x 3 columns]
